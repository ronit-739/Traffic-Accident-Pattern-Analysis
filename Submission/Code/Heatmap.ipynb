# %%
#Get data from csv file

import pandas as pd

df = pd.read_csv("../Data/Nepal_RoadAccidents_Cleaned.csv")

df.head(3)
# Out:
#   Accident_ID  Year  Month Month_Name Accident_Date Province   District  \
# 0   ACC-00031  2021      1    January    2021-01-01  Bagmati  Kathmandu
# 1   ACC-00051  2021      1    January    2021-01-01  Bagmati  Kathmandu
# 2   ACC-00062  2021      1    January    2021-01-01  Bagmati  Kathmandu
#
#     City / Place   Latitude  Longitude  ... Time_of_Day Weather_Condition  \
# 0  Kalanki Chowk  27.702856  85.273929  ...     Evening             Foggy
# 1  Kalanki Chowk  27.696149  85.277415  ...     Morning             Rainy
# 2  Kalanki Chowk  27.698161  85.277734  ...     Evening             Clear
#
#   Number_of_Vehicles_Involved Injuries Fatalities  Total_People_Killed  \
# 0                           1        0          0                    0
# 1                           2        8          0                    0
# 2                           1        7          1                    1
#
#    Emergency_Response_Time_Minutes  Victim_Gender     Victim_Age_Group  \
# ...

# %% [markdown]
# Heatmap of major accident places in nepal

# %%
import folium
from folium.plugins import HeatMap


map_center = [df["Latitude"].mean(), df["Longitude"].mean()]  #Finds the average location of all the accidents

m = folium.Map(location=map_center, zoom_start=7) #Creates a folium map centered around the average location 

heat_data = df[["Latitude", "Longitude"]].values.tolist() #Converts the latitude and longitude columns into a list of lists

HeatMap(heat_data).add_to(m) #Adds the heatmap layer to the folium map

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %% [markdown]
# Temporal Distribution of Accidents

# %%
time_counts = df["Time_of_Day"].value_counts()
print(time_counts)
# Out:
# Time_of_Day
# Night        1502
# Evening      1360
# Morning      1264
# Afternoon     874
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-v0_8')

time_counts.plot(kind="bar")

plt.title("Accidents by Time of Day")
plt.xlabel("Time of Day")
plt.ylabel("Number of Accidents")

plt.savefig('_Figures/time_of_day_accidents.png', bbox_inches='tight')

plt.show()

# %% [markdown]
# Accidents by Road type

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-v0_8')

road_counts = df["Road_Type"].value_counts()
print(road_counts)

road_counts.plot(kind='pie', autopct='%1.1f%%', startangle=140)

plt.title("Accidents by Road Type")
plt.xlabel("Road Type")
plt.ylabel("")

plt.savefig('_Figures/road_type_analysis.png', bbox_inches='tight')

plt.show()
# Out:
# Road_Type
# Highway       2104
# Urban Road    1639
# Hill Road      658
# Rural Road     374
# Ring Road      225
# Name: count, dtype: int64

# %% [markdown]
# Analyze Accidents by Weather Condition

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-v0_8')

weather_counts = df["Weather_Condition"].value_counts()
print(weather_counts)

weather_counts.plot(kind="line")

plt.title("Accidents by Weather Condition")
plt.xlabel("Weather")
plt.ylabel("Number of Accidents")

plt.savefig('_Figures/weather_condition_analysis.png', bbox_inches='tight')

plt.show()
# Out:
# Weather_Condition
# Clear    2228
# Rainy    1768
# Foggy    1004
# Name: count, dtype: int64
