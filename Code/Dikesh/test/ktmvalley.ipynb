# %% [markdown]
# Import Required Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import folium
from sklearn.cluster import DBSCAN

# %% [markdown]
# Load the Kathmandu road accidents dataset

# %%
df = pd.read_csv("data/KTM_RoadAccidents_Cleaned.csv")

# Display first few rows to understand the data structure
print("Dataset Preview:")
display(df.head())

# Display basic information about the dataset
print("\nDataset Information:")
df.info()
# Out:
# Dataset Preview:
#   Accident_ID  Year  Month Month_Name Accident_Date Province   District  \
# 0     KV-0031  2021      1    January    2021-01-01  Bagmati  Kathmandu
# 1     KV-0051  2021      1    January    2021-01-01  Bagmati  Kathmandu
# 2     KV-0062  2021      1    January    2021-01-01  Bagmati  Kathmandu
# 3     KV-0209  2021      1    January    2021-01-01  Bagmati  Kathmandu
# 4     KV-0281  2021      1    January    2021-01-01  Bagmati  Kathmandu
#
#       City / Place   Latitude  Longitude  ... Time_of_Day Weather_Condition  \
# 0    Kalanki Chowk  27.702856  85.273929  ...     Evening             Foggy
# 1    Kalanki Chowk  27.696149  85.277415  ...     Morning             Rainy
# 2    Kalanki Chowk  27.698161  85.277734  ...     Evening             Clear
# 3  Koteshwor Chowk  27.677999  85.346622  ...   Afternoon             Rainy
# 4          Tinkune  27.686164  85.344181  ...       Night             Clear
#
#   Number_of_Vehicles_Involved Injuries Fatalities  Total_People_Killed  \
# 0                           1        0          0                    0
# 1                           2        8          0                    0
# 2                           1        7          1                    1
# 3                           2        4          1                    1
# 4                           2        7          0                    0
#
#    Emergency_Response_Time_Minutes  Victim_Gender     Victim_Age_Group  \
# 0                               72         Female  Young Adult (15-24)
# 1                               35         Female  Middle Aged (45-64)
# 2                               61           Male  Middle Aged (45-64)
# 3                               23           Male        Adult (25-44)
# 4                               13         Female  Middle Aged (45-64)
#
#    Road_User_Type
# 0    Motorcyclist
# 1       Passenger
# 2    Motorcyclist
# 3       Passenger
# 4       Passenger
#
# [5 rows x 23 columns]
# Dataset Information:
# <class 'pandas.DataFrame'>
# RangeIndex: 1672 entries, 0 to 1671
# Data columns (total 23 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Accident_ID                      1672 non-null   str
#  1   Year                             1672 non-null   int64
#  2   Month                            1672 non-null   int64
#  3   Month_Name                       1672 non-null   str
#  4   Accident_Date                    1672 non-null   str
#  5   Province                         1672 non-null   str
#  6   District                         1672 non-null   str
#  7   City / Place                     1672 non-null   str
#  8   Latitude                         1672 non-null   float64
#  9   Longitude                        1672 non-null   float64
#  10  Road_Type                        1672 non-null   str
#  11  Vehicle_Type                     1672 non-null   str
#  12  Accident_Cause                   1672 non-null   str
#  13  Time_of_Day                      1672 non-null   str
#  14  Weather_Condition                1672 non-null   str
#  15  Number_of_Vehicles_Involved      1672 non-null   int64
#  16  Injuries                         1672 non-null   int64
#  17  Fatalities                       1672 non-null   int64
#  18  Total_People_Killed              1672 non-null   int64
#  19  Emergency_Response_Time_Minutes  1672 non-null   int64
#  20  Victim_Gender                    1672 non-null   str
#  21  Victim_Age_Group                 1672 non-null   str
#  22  Road_User_Type                   1672 non-null   str
# dtypes: float64(2), int64(7), str(14)
# memory usage: 300.6 KB

# %% [markdown]
# Data Cleaning

# %%
print(f"Original dataset size: {len(df)} rows")
df = df.dropna(subset=["Latitude", "Longitude"])
print(f"After removing missing coordinates: {len(df)} rows")

# Remove duplicate records to avoid biased clustering
df = df.drop_duplicates()
print(f"After removing duplicates: {len(df)} rows")
# Out:
# Original dataset size: 1672 rows
# After removing missing coordinates: 1672 rows
# After removing duplicates: 1672 rows

# %% [markdown]
# Simple scatter plot to see the distribution of accidents

# %%
plt.figure(figsize=(12, 8))
plt.scatter(df["Longitude"], df["Latitude"], alpha=0.5, s=10)
plt.xlabel("Longitude", fontsize=12)
plt.ylabel("Latitude", fontsize=12)
plt.title("Traffic Accident Locations in Nepal", fontsize=14, fontweight='bold')
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# Prepare Data for DBSCAN Clustering

# %%
# Convert latitude and longitude to radians for haversine distance calculation
# Haversine formula calculates distances on a sphere (Earth)
coords_radians = np.radians(df[["Latitude", "Longitude"]].values)

# Define clustering parameters
eps_km = 0.4  # Maximum distance between two points to be considered neighbors (in km) for ktm(0.5),nepal(0.005)
eps_radians = eps_km / 6371.0  # Convert km to radians (Earth's radius = 6371 km)
min_samples = 3  # Minimum number of points to form a dense region (cluster)

print(f"DBSCAN Parameters:")
print(f"  - eps (radius): {eps_km} km")
print(f"  - min_samples: {min_samples} points")
print(f"  - metric: haversine (accounts for Earth's curvature)")
# Out:
# DBSCAN Parameters:
#   - eps (radius): 0.4 km
#   - min_samples: 3 points
#   - metric: haversine (accounts for Earth's curvature)

# %% [markdown]
# Apply DBSCAN Clustering Algorithm

# %%
# Initialize DBSCAN model with specified parameters
# - ball_tree algorithm is efficient for haversine metric
# - haversine metric calculates great-circle distances
dbscan_model = DBSCAN(
    eps=eps_radians,
    min_samples=min_samples,
    algorithm='ball_tree',
    metric='haversine'
)

# Fit the model and predict cluster labels
# Cluster -1 represents noise (outlier points that don't belong to any cluster)
df["cluster"] = dbscan_model.fit_predict(coords_radians)

# %% [markdown]
# Analyze Clustering Results

# %%
# Display clustering statistics
num_clusters = df["cluster"].nunique() - 1  # Exclude -1 (noise)
num_noise = (df["cluster"] == -1).sum()
num_clustered = (df["cluster"] != -1).sum()

print("\n" + "="*60)
print("DBSCAN CLUSTERING RESULTS")
print("="*60)
print(f"Total accidents analyzed: {len(df)}")
print(f"Number of clusters identified: {num_clusters}")
print(f"Clustered points (hotspots): {num_clustered} ({num_clustered/len(df)*100:.1f}%)")
print(f"Noise points (isolated accidents): {num_noise} ({num_noise/len(df)*100:.1f}%)")
print("\nTop 10 Largest Clusters:")
print(df[df["cluster"] != -1]["cluster"].value_counts().head(10))
# Out:
# ============================================================
# DBSCAN CLUSTERING RESULTS
# ============================================================
# Total accidents analyzed: 1672
# Number of clusters identified: 22
# Clustered points (hotspots): 1611 (96.4%)
# Noise points (isolated accidents): 61 (3.6%)
#
# Top 10 Largest Clusters:
# cluster
# 1     423
# 3     366
# 4     218
# 9     139
# 0     124
# 2      94
# 7      61
# 5      56
# 6      55
# 11     21
# Name: count, dtype: int64

# %% [markdown]
# Visualize Accident Hotspot Clusters

# %%
# Create a detailed visualization separating noise from clusters
noise_points = df[df["cluster"] == -1]
clustered_points = df[df["cluster"] != -1]

fig, ax = plt.subplots(figsize=(14, 10))

# Plot noise points in light grey
ax.scatter(
    noise_points["Longitude"],
    noise_points["Latitude"],
    c="lightgrey",
    s=5,
    alpha=0.3,
    label="Noise (Isolated Accidents)"
)

# Plot clustered points with rainbow colors
scatter = ax.scatter(
    clustered_points["Longitude"],
    clustered_points["Latitude"],
    c=clustered_points["cluster"],
    cmap="rainbow",
    s=15,
    alpha=0.7,
    edgecolors='black',
    linewidth=0.5
)

# Add colorbar to show cluster IDs
cbar = plt.colorbar(scatter, ax=ax, label="Cluster ID")
cbar.ax.tick_params(labelsize=10)

# Customize plot
ax.set_xlabel("Longitude", fontsize=12, fontweight='bold')
ax.set_ylabel("Latitude", fontsize=12, fontweight='bold')
ax.set_title(
    f"Traffic Accident Hotspot Clusters\n"
    f"{num_clusters} hotspots identified | {num_clustered} accidents in clusters",
    fontsize=14,
    fontweight='bold',
    pad=20
)
ax.legend(loc='upper right', fontsize=10)
ax.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# Analyze Cluster Locations

# %%
# Group accidents by cluster and identify top locations
if "City / Place" in df.columns:
    cluster_summary = df[df["cluster"] != -1].groupby("cluster").agg(
        accident_count=("City / Place", "count"),
        top_location=("City / Place", lambda x: x.value_counts().index[0] if len(x) > 0 else "Unknown"),
        avg_latitude=("Latitude", "mean"),
        avg_longitude=("Longitude", "mean")
    ).sort_values("accident_count", ascending=False)
    
    print("\n" + "="*60)
    print("TOP 15 ACCIDENT HOTSPOT CLUSTERS")
    print("="*60)
    display(cluster_summary.head(15))
# Out:
# ============================================================
# TOP 15 ACCIDENT HOTSPOT CLUSTERS
# ============================================================
#          accident_count           top_location  avg_latitude  avg_longitude
# cluster
# 1                   423        Koteshwor Chowk     27.688025      85.347459
# 3                   366              Lagankhel     27.666064      85.317086
# 4                   218          Balaju Bypass     27.736159      85.318452
# 9                   139            Thimi Chowk     27.685385      85.395685
# 0                   124          Kalanki Chowk     27.695881      85.277290
# 2                    94               Chabahil     27.718702      85.354322
# 7                    61              Ratnapark     27.704612      85.313494
# 5                    56           Suryabinayak     27.660303      85.413083
# 6                    55       Bhaktapur Durbar     27.670700      85.426917
# 11                   21          Godawari Road     27.597713      85.374217
# 10                   10  Tribhuvan Hwy Thankot     27.657566      85.215725
# 8                     6  Tribhuvan Hwy Thankot     27.669148      85.217550
# 14                    6  Tribhuvan Hwy Thankot     27.665442      85.225844
# 17                    6  Tribhuvan Hwy Thankot     27.666359      85.207367
# 13                    5         Arniko Highway     27.670813      85.405836

# %% [markdown]
# Map

# %%
#Calculate center of the map (mean of all coordinates)
center_lat = df["Latitude"].mean()
center_lon = df["Longitude"].mean()

# Create base map centered on the accident locations
accident_map = folium.Map(
    location=[center_lat, center_lon],
    zoom_start=12,
    tiles='OpenStreetMap'
)

# Add cluster markers with different colors
# Define color palette for clusters
colors = ['red', 'blue', 'green', 'purple', 'orange', 'darkred',
          'lightred', 'black', 'darkblue', 'darkgreen', 'cadetblue',
          'darkpurple', 'pink', 'lightblue', 'lightgreen', 'gray','gold','lightgray','black','cyan','magenta']

# Add clustered points
for cluster_id in sorted(df[df["cluster"] != -1]["cluster"].unique()):
    cluster_data = df[df["cluster"] == cluster_id]
    color = colors[cluster_id % len(colors)]
    
    for _, row in cluster_data.iterrows():
        folium.CircleMarker(
            location=[row["Latitude"], row["Longitude"]],
            radius=4,
            color=color,
            fill=True,
            fillColor=color,
            fillOpacity=0.6,
            popup=f"Cluster {cluster_id}"
        ).add_to(accident_map)

# Add noise points in grey
for _, row in noise_points.iterrows():
    folium.CircleMarker(
        location=[row["Latitude"], row["Longitude"]],
        radius=2,
        color='gray',
        fill=True,
        fillColor='gray',
        fillOpacity=0.3,
        popup="Isolated Accident"
    ).add_to(accident_map)

# Save the map
accident_map.save("fig/accident_hotspots.html")
print("\nInteractive map saved as 'fig/accident_hotspots.html'")

# Display map in notebook
accident_map
# Out:
# Interactive map saved as 'accident_hotspots.html'
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_722ca94d0a6f4cc5de52cc90d390623f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_722ca94d0a6f4cc5de52cc90d390623f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_722ca94d0a6f4cc5de52cc90d390623f = L.map(
#                 &quot;map_722ca94d0a6f4cc5de52cc90d390623f&quot;,
#                 {
#                     center: [27.688224636363636, 85.33694828588517],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b4598ae66bd32d0177cd2df7a96e06c7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b4598ae66bd32d0177cd2df7a96e06c7.addTo(map_722ca94d0a6f4cc5de52cc90d390623f);
#
#
#             var circle_marker_795c058f4a30f9aef2d407e94735421c = L.circleMarker(
#                 [27.702856, 85.273929],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_722ca94d0a6f4cc5de52cc90d390623f);
#
#
#         var popup_34672ffb3c5c26203a7b87dfd57848bd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_82b07526dd2fda371d27c3eb8b1d2002 = $(`&lt;div id=&quot;html_82b07526dd2fda371d27c3eb8b1d2002&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cluster 0&lt;/div&gt;`)[0];
#                 popup_34672ffb3c5c26203a7b87dfd57848bd.setContent(html_82b07526dd2fda371d27c3eb8b1d2002);
#
#
#
#         circle_marker_795c058f4a30f9aef2d407e94735421c.bindPopup(popup_34672ffb3c5c26203a7b87dfd57848bd)
#         ;
#
#
#
#
#             var circle_marker_448bdb065f1664d7dc281f7899e96d9e = L.circleMarker(
#                 [27.696149, 85.277415],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_722ca94d0a6f4cc5de52cc90d390623f);
#
#
#         var popup_a1b977480abc073708041bb1905f4b66 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7e07f22335ab3c839ebfaeb2b3397f14 = $(`&lt;div id=&quot;html_7e07f22335ab3c839ebfaeb2b3397f14&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cluster 0&lt;/div&gt;`)[0];
#                 popup_a1b977480abc073708041bb1905f4b66.setContent(html_7e07f22335ab3c839ebfaeb2b3397f14);
#
#
#
#         circle_marker_448bdb065f1664d7dc281f7899e96d9e.bindPopup(popup_a1b977480abc073708041bb1905f4b66)
#         ;
#
#
#
#
#             var circle_marker_35eb4d203a7e2cf9e488287b5ea29fd5 = L.circleMarker(
#                 [27.698161, 85.277734],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_722ca94d0a6f4cc5de52cc90d390623f);
#
#
#         var popup_df2cad5c1675ae6ec1ee2846c4192baa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_409741f8cc5d5afc9ef8492ae427eef1 = $(`&lt;div id=&quot;html_409741f8cc5d5afc9ef8492ae427eef1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cluster 0&lt;/div&gt;`)[0];
#                 popup_df2cad5c1675ae6ec1ee2846c4192baa.setContent(html_409741f8cc5d5afc9ef8492ae427eef1);
#
#
#
#         circle_marker_35eb4d203a7e2cf9e488287b5ea29fd5.bindPopup(popup_df2cad5c1675ae6ec1ee2846c4192baa)
#         ;
#
#
#
#
#             var circle_marker_0db98b13783eea19dcb3368c50232bc2 = L.circleMarke
